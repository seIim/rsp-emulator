# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'axes.linewidth'    : 0.4,
                     'ytick.major.width' : 0.4,
                     'ytick.minor.width' : 0.4,
                     'xtick.major.width' : 0.4,
                     'xtick.minor.width' : 0.4,
                     'xtick.major.size'  : 4,
                     'ytick.major.size'  : 4,
                     'xtick.minor.visible' : 'True',
                     'ytick.minor.visible' : 'True',
                     'xtick.labelsize': 8, 
                     'ytick.labelsize': 8,
                     'axes.labelsize' : 8,
                     'font.family': 'Serif',
                     'figure.figsize': (15/3, 3.3),
                     'figure.dpi' : 200,
                     'ytick.right': 'True',
                     'xtick.top'  : 'True',
                     'ytick.direction': 'in',
                     'xtick.direction': 'in',
                     'axes.spines.top': 'True',
                     'axes.grid': 'False',
                     'grid.linestyle': '--',
                     'grid.linewidth': 0.25
                    })
sns.set_palette('deep')

# %%
import new

# %%
from utils import *
from dataloader import *
import jax.numpy as jnp
import jax, jax.random as random
from inference import infer_inputs

# %%
# jax.config.update("jax_default_matmul_precision", "high")
# import os
# os.environ['XLA_FLAGS'] = (
#     '--xla_gpu_triton_gemm_any=True '
#     '--xla_gpu_enable_latency_hiding_scheduler=true ')

# %%
X, y = create_dataset(sequence_length=100)
key1, key2 = random.split(random.PRNGKey(42))
X_train, y_train, X_test, y_test = train_test_split(key1, X, y, split=0.2, shuffle=True)
mu = X_train.mean(axis=0)
sd = X_train.std(axis=0)
std_y = y_train.std()
y_train = y_train/std_y
y_test = y_test/std_y
X_train = (X_train - mu)/sd
X_test = (X_test - mu)/sd
input_dim  = X_train.shape[1]
output_dim = y_train.shape[1]

# %%
plt.hist(X_train[:,0])
plt.show()

# %%
model = new.ImprovedTransformer()
s = load_model('new_arch_res')
from functools import partial
body_fn = jax.jit(partial(model.apply, s['state']['params']))
# Out:
# /home/sk3365/.conda/envs/gpujax/lib/python3.13/site-packages/orbax/checkpoint/type_handlers.py:1330: UserWarning: Couldn't find sharding info under RestoreArgs. Populating sharding info from sharding file. Please note restoration time will be slightly increased due to reading from file instead of directly from RestoreArgs. Note also that this option is unsafe when restoring on a different topology than the checkpoint was saved with.
#   warnings.warn(

# %%
y_pred = body_fn(X_test[100].reshape(-1,5))
@jax.jit
def loss_fn(X):
    pred = body_fn(X.reshape(1,-1)).squeeze()
    return jnp.mean((pred - y_test[100])**2)
	
X_init = jax.scipy.optimize.minimize(
        loss_fn, jnp.zeros(5), method='BFGS').x

# %%
x = X_init.reshape(-1,5)
x = jnp.repeat(x, 100, axis=0)
x = x + 1e-1*random.normal(random.key(11),shape=(x.shape))
y_preds = body_fn(x)
y_preds.shape
# Out:
# (100, 100)

# %%
phase = jnp.arange(100)
for pred in y_preds:
	plt.plot(phase, pred, alpha=0.25, c='grey')
plt.plot(phase, body_fn(jnp.array([-0.05949636, -0.83456725, -2.2712946 ,  0.01797971,  1.4692581 ]).reshape(1,5)).flatten(), c='red')
plt.plot(phase, y_test[100])

# %% [markdown]
# # Hamiltonian Monte Carlo

# %%
from numpyro.infer import MCMC, NUTS, init_to_median
from numpyro.infer.initialization import init_to_value
import numpyro.distributions as dist
import numpyro

# %%
def loss_fn(X, y=None):
    pred = body_fn(X.reshape(1,-1)).squeeze()
    return jnp.mean((pred - y)**2)

X_init = jax.scipy.optimize.minimize(
    partial(loss_fn, y=y_test[100]), jnp.zeros(5), method='BFGS').x
init_params = {'features': X_init}

def model(y_obs):
	with numpyro.plate('f', 1):
	    X = numpyro.sample("features",
						   dist.ImproperUniform(dist.constraints.interval(-3,3),
											   event_shape=(5,), batch_shape=(1,)))
		
	pred = body_fn(X.reshape(1,-1)).squeeze()
	noise_scale = numpyro.sample("noise", dist.HalfNormal(0.01))
	numpyro.sample(
        "obs",
        dist.Normal(pred, noise_scale),
        obs=y_test
    )

# %%
num_warmup=2500
num_samples=500
nuts_kernel = NUTS(
    model,
    adapt_step_size=True,
    adapt_mass_matrix=True,
	init_strategy=init_to_value(values=init_params),
    target_accept_prob=0.99,
    max_tree_depth=12
)
mcmc = MCMC(
    nuts_kernel,
    num_warmup=num_warmup,
    num_samples=num_samples,
)

# %%
key = random.key(42)
mcmc.run(
    rng_key=key,
    y_obs=y_test[100],
)
# Out:
# sample: 100%|██████████| 3000/3000 [04:20<00:00, 11.54it/s, 127 steps of size 2.30e-02. acc. prob=0.99]

# %%
mcmc.print_summary()
# Out:
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# features[0]     -1.50      0.04     -1.50     -1.57     -1.42    163.01      1.00
# features[1]      0.47      0.04      0.47      0.39      0.53    170.45      1.00
# features[2]     -1.04      0.02     -1.04     -1.06     -1.01    177.86      1.00
# features[3]      1.14      0.02      1.14      1.11      1.17    200.47      1.00
# features[4]      0.36      0.01      0.36      0.34      0.38    182.44      1.02
#       noise      0.40      0.00      0.40      0.39      0.40    352.62      1.00
#
# Number of divergences: 0

# %%
mcmc.get_samples()['features'].mean(axis=0), X_test[100], x[0]
# Out:
# (Array([-1.5008323 ,  0.46745425, -1.0376053 ,  1.1357046 ,  0.35960323],      dtype=float32),
#  Array([-0.07406374,  0.06459364,  0.98112893,  1.81038   , -0.33079898],      dtype=float32),
#  Array([-1.0029049 ,  0.8605566 ,  0.44041193,  1.3069202 , -0.34729603],      dtype=float32))

# %% [markdown]
# # SVI

# %%
from numpyro.infer import SVI, Trace_ELBO, init_to_value
from numpyro.infer.autoguide import AutoLaplaceApproximation
import optax

# %%
num_steps = 100000
learning_rate = 5e-4

# %%
optimizer = optax.adamw(learning_rate)
guide = AutoLaplaceApproximation(model)
svi = SVI(model, guide, optimizer, loss=Trace_ELBO())
rng_key = random.key(42)
svi_result = svi.run(rng_key, num_steps, y_test[100], init_params=init_params)

params = svi_result.params
losses = svi_result.losses
# Out:
# 100%|██████████| 100000/100000 [01:54<00:00, 870.34it/s, init loss: 3168764.0000, avg. loss [95001-100000]: 41137.2461]

# %%
params
# Out:
# {'auto_loc': Array([-0.06594701, -0.8795046 , -2.283314  , -0.00282233,  1.2653651 ,
#         -0.92738193], dtype=float32)}
